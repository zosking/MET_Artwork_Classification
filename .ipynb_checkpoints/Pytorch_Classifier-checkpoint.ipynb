# %% [markdown]
# # Building Class to Input Image Data Into Classifier

# %%
from __future__ import print_function, division
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils


# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

plt.ion()   # interactive mode

# %% [markdown]
# # Setup of Dataset Classes and Image Import

# %%
departments_frame = pd.read_csv('Images/picture_names_and_department.csv')

n = len(departments_frame)
img_name = departments_frame.iloc[:, 2]
dept_name = departments_frame.iloc[:, 1]
art_name = departments_frame.iloc[:, 0]

print('Image name: {}'.format(img_name[:4]))
print('Department name: {}'.format(dept_name[:4]))
print('Art name: {}'.format(art_name[:4]))
# Out:
# Image name: 0    37_DP247752.jpg
# 1    38_DP247753.jpg
# 2       39_37808.jpg
# 3      40_174118.jpg
# Name: Picture_name, dtype: object
# Department name: 0    The American Wing
# 1    The American Wing
# 2    The American Wing
# 3    The American Wing
# Name: department, dtype: object
# Art name: 0    37
# 1    38
# 2    39
# 3    40
# Name: Unnamed: 0, dtype: int64

# %%
class ArtDepartmentDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, csv_file, root_dir, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.departments_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.images = self.departments_frame.Picture_name
        self.labels = self.departments_frame.department
        
    def __len__(self):
        return len(self.departments_frame)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir,
                                self.departments_frame.iloc[idx, 2])
        dept_name = os.path.join(self.root_dir,
                                self.departments_frame.iloc[idx, 1])
        image = io.imread(img_name, as_gray=True)
        dept = self.departments_frame.iloc[idx, 3]
        sample = {'image': image, 'department': dept}

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
class Rescale(object):
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size

    def __call__(self, sample):
        image, department = sample['image'], sample['department']
        
        h, w = image.shape[:2]
        
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)

        img = transform.resize(image, (new_h, new_w))

        return {'image': img, 'department': department}
    
class RandomCrop(object):
    """Crop randomly the image in a sample.

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        image, department = sample['image'], sample['department']

        h, w = image.shape[:2]
        new_h, new_w = self.output_size

        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)

        image = image[top: top + new_h,
                      left: left + new_w]

        return {'image': image, 'department': department}

class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, department = sample['image'], sample['department']

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose(( 0, 1))
        image = torch.from_numpy(image)
        image = torch.unsqueeze(image, 0)
        image = image.float()
        in_transform = transforms.Compose([transforms.Normalize(mean = (0.5,), std = (0.5,))])
        image = in_transform(image)
        return {'image': image,
                'department': department}

# %% [markdown]
# # Building Classifier

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split
from torch.utils.data.sampler import SubsetRandomSampler

# %% [markdown]
# ## First Pass with Simple Classifier Architecture

# %%
#first pass attempt to create simple classifier
dataset = ArtDepartmentDataset(csv_file='Images/picture_names_and_department.csv',
                                    root_dir='Images/', 
                                    transform=transforms.Compose([
                                               Rescale(110),
                                               RandomCrop(100),
                                               ToTensor()
                                           ]))
batch_size = 8
validation_split = .80
shuffle_dataset = True
random_seed= 42

# Creating data indices for training and validation splits:
dataset_size = len(dataset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
trainset = SubsetRandomSampler(train_indices)
testset = SubsetRandomSampler(val_indices)

trainloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                           sampler=trainset)
testloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                sampler=testset)

classes = ('Ancient Near Eastern Art', 'Arms and Armor','Asian Art', 
           'Costume Institute','Egyptian Art','European Sculpture and Decorative Arts',
           'Greek and Roman Art', 'Islamic Art','Medieval Art', 'The American Wing')

# %%
import matplotlib.pyplot as plt
import numpy as np
#example images of a single batch
#functions to show an image

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)), cmap='Greys', vmin=0, vmax=255)
    plt.show()


#get some random training images
dataiter = iter(trainloader)
images  = dataiter.next()['image']
labels = dataiter.next()['department']

#show images
imshow(torchvision.utils.make_grid(images))
#print labels
print(', '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Egyptian Art, Ancient Near Eastern Art, Asian Art, Asian Art

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#simple CNN with two convolutional layers and 3 fully connected layers
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net()
print(net)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
# Out:
# Net(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %% [markdown]
# The criterion and optimizer were referenced in *Fine-tuning Convolutional Neural Networks for fine art classification* (Cetinic et al.) as working best for art classification.

# %% [markdown]
# ## TensorBoard Setup

# %%
from torch.utils.tensorboard import SummaryWriter

# default `log_dir` is "runs" - we'll be more specific here
writer = SummaryWriter('runs/art_classifier_1_moredata_normalized_downscaled_b16')

# %%
def matplotlib_imshow(img, one_channel=False):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
# get some random training images
dataiter = iter(trainloader)
images = dataiter.next()['image']
labels = dataiter.next()['department']

# create grid of images
img_grid = torchvision.utils.make_grid(images)

# show images
matplotlib_imshow(img_grid, one_channel=True)

# write to tensorboard
writer.add_image('batch_art_images', img_grid)

# %%
writer.add_graph(net, images)
writer.close()

# %% [markdown]
# #### Opening TensorBoard:
# **Terminal:** tensorboard --logdir=runs/ --host localhost --port 8088 \
# **Browser:** http://localhost:8088
# <br>
# <br>
# *TensorBoard was used for the visualization and real-time monitoring of model training

# %%
# helper functions

def images_to_probs(net, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
    output = net(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]


def plot_classes_preds(net, images, labels):
    '''
    Generates matplotlib Figure using a trained network, along with images
    and labels from a batch, that shows the network's top prediction along
    with its probability, alongside the actual label, coloring this
    information based on whether the prediction was correct or not.
    Uses the "images_to_probs" function.
    '''
    preds, probs = images_to_probs(net, images)
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(12, 48))
    for idx in np.arange(4):
        ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
        matplotlib_imshow(images[idx], one_channel=True)
        ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
            classes[preds[idx]],
            probs[idx] * 100.0,
            classes[labels[idx]]),
                    color=("green" if preds[idx]==labels[idx].item() else "red"))
    return fig

def add_pr_curve_tensorboard(class_index, test_probs, test_preds, global_step=0):
    '''
    Takes in a "class_index" from 0 to 9 and plots the corresponding
    precision-recall curve
    '''
    tensorboard_preds = test_preds == class_index
    tensorboard_probs = test_probs[:, class_index]

    writer.add_pr_curve(classes[class_index],
                        tensorboard_preds,
                        tensorboard_probs,
                        global_step=global_step)
    writer.close()

# %% [markdown]
# ## Training the Classifier

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# %%time

#two epochs initially chosen as proof of concept with simple classifier
for epoch in range(2):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs = data['image']
        labels = data['department']

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 1000 == 999:
            
                writer.add_scalar('training loss',
                                  running_loss / 1000,
                                  epoch * len(trainloader) + i)
                writer.add_figure('predictions vs. actuals',
                                  plot_classes_preds(net, inputs, labels),
                                  global_step=epoch * len(trainloader) + i)
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 2000))
                running_loss = 0.0

print('Finished Training')
# Out:
# [1,  1000] loss: 1.095
# [2,  1000] loss: 1.054
# Finished Training
# CPU times: user 19min 25s, sys: 6.63 s, total: 19min 32s
# Wall time: 23min 34s

# %%
#save model
PATH = './art_net1.pth'
torch.save(net.state_dict(), PATH)

# %% [markdown]
# ## Testing the Classifier

# %%
#example images from test set
dataiter = iter(testloader)
images = dataiter.next()['image']
labels = dataiter.next()['department']

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# GroundTruth:  European Sculpture and Decorative Arts Greek and Roman Art Medieval Art Asian Art

# %%
#load model
net = Net()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
#sample predictions
outputs = net(images)

_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:  Greek and Roman Art Asian Art Asian Art Asian Art

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images = data['image']
        labels = data['department']
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 26 %

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images = data['image']
        labels = data['department']
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of Ancient Near Eastern Art :  0 %
# Accuracy of Arms and Armor :  0 %
# Accuracy of Asian Art : 85 %
# Accuracy of Costume Institute :  2 %
# Accuracy of Egyptian Art : 30 %
# Accuracy of European Sculpture and Decorative Arts :  6 %
# Accuracy of Greek and Roman Art : 13 %
# Accuracy of Islamic Art :  0 %
# Accuracy of Medieval Art :  0 %
# Accuracy of The American Wing :  0 %

# %% [markdown]
# The overall accuracy of this model was 26%, which is not acceptable. When breaking accuracy out by class it becomes clear that with this setup the model only begins to define features for half of the classes present. However, there are many parameters that can be tuned to improve the performance of this model.

# %% [markdown]
# # Tuning the Classifier

# %%
#changing image scale and crop for future use with transfer learning
dataset = ArtDepartmentDataset(csv_file='Images/picture_names_and_department.csv',
                                    root_dir='Images/', 
                                    transform=transforms.Compose([
                                               Rescale(250),
                                               RandomCrop(224),
                                               ToTensor()
                                           ]))
batch_size = 8
#increasing the number of images held out for validation
validation_split = .70
shuffle_dataset = True
random_seed= 42

# Creating data indices for training and validation splits:
dataset_size = len(dataset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
trainset = SubsetRandomSampler(train_indices)
testset = SubsetRandomSampler(val_indices)

trainloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                           sampler=trainset)
testloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                sampler=testset)

classes = ('Ancient Near Eastern Art', 'Arms and Armor','Asian Art', 
           'Costume Institute','Egyptian Art','European Sculpture and Decorative Arts',
           'Greek and Roman Art', 'Islamic Art','Medieval Art', 'The American Wing')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#added a convolutional layer and expanded the number of nodes in the fully connected layers
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 64, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 32, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(32, 64, 5)
        self.fc1 = nn.Linear(64 * 24 * 24, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 84)
        self.fc4 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 64 * 24 * 24)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

net = Net()
print(net)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
# Out:
# Net(
#   (conv1): Conv2d(1, 64, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=36864, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=84, bias=True)
#   (fc4): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter('runs/art_classifier_3_more_layers_epochs20')

# %%
#training image examples printed and written to TensorBoard for posterity
dataiter = iter(trainloader)
images = dataiter.next()['image']
labels = dataiter.next()['department']

img_grid = torchvision.utils.make_grid(images)

matplotlib_imshow(img_grid, one_channel=True)

writer.add_image('batch_art_images', img_grid)

# %%
writer.add_graph(net, images)
writer.close()

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# %%time

#increased number of epochs to ten
for epoch in range(20):

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs = data['image']
        labels = data['department']

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 1000 == 999:
            
                writer.add_scalar('training loss',
                                  running_loss / 1000,
                                  epoch * len(trainloader) + i)
                writer.add_figure('predictions vs. actuals',
                                  plot_classes_preds(net, inputs, labels),
                                  global_step=epoch * len(trainloader) + i)
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 2000))
                running_loss = 0.0

print('Finished Training')
# Out:
# [1,  1000] loss: 1.089
# [1,  2000] loss: 1.041
# [1,  3000] loss: 1.014
# [2,  1000] loss: 0.993
# [2,  2000] loss: 0.972
# [2,  3000] loss: 0.962
# [3,  1000] loss: 0.938
# [3,  2000] loss: 0.933
# [3,  3000] loss: 0.922
# [4,  1000] loss: 0.903
# [4,  2000] loss: 0.891
# [4,  3000] loss: 0.889
# [5,  1000] loss: 0.870
# [5,  2000] loss: 0.857
# [5,  3000] loss: 0.839
# [6,  1000] loss: 0.828
# [6,  2000] loss: 0.823
# [6,  3000] loss: 0.815
# [7,  1000] loss: 0.791
# [7,  2000] loss: 0.801
# [7,  3000] loss: 0.778
# [8,  1000] loss: 0.762
# [8,  2000] loss: 0.760
# [8,  3000] loss: 0.747
# [9,  1000] loss: 0.737
# [9,  2000] loss: 0.725
# [9,  3000] loss: 0.727
# [10,  1000] loss: 0.697
# [10,  2000] loss: 0.706
# [10,  3000] loss: 0.711
# [11,  1000] loss: 0.674
# [11,  2000] loss: 0.679
# [11,  3000] loss: 0.676
# [12,  1000] loss: 0.652
# [12,  2000] loss: 0.652
# [12,  3000] loss: 0.658

# %%
PATH = './art_classifier_3_more_layers_epochs20.pth'
torch.save(net.state_dict(), PATH)

# %%
net = Net()
net.load_state_dict(torch.load(PATH))

# %%
correct = 0
total = 0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
all_preds = torch.tensor([])
all_labels = torch.tensor([])

with torch.no_grad():
    for data in testloader:
        images = data['image']
        labels = data['department']
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        all_preds = torch.cat(
            (all_preds, outputs)
            ,dim=0
        )
        all_labels = torch.cat(
            (all_labels, labels)
            ,dim=0
        )
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# To better visualize the performance of this model, a confusion matrix is generated. There is not a PyTorch native function for doing this, SciKitLearn must be used and some other functions must be defined. Thank you to "DeepLizard" tutorial for code below.

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def get_num_correct(preds, labels):
    return preds.argmax(dim=1).eq(labels).sum().item()

preds_correct = get_num_correct(all_preds, all_labels)

print('total correct:', preds_correct)
print('accuracy:', preds_correct / len(all_labels))
# Out:
# total correct: 32151
# accuracy: 0.49753176212067285

# %%
cm = confusion_matrix(all_labels, all_preds.argmax(dim=1))

plt.figure(figsize=(12,12))
plot_confusion_matrix(cm, classes)
# Out:
# Confusion matrix, without normalization
# [[ 1327    18  1065   112   634   202   281   265   383    23]
#  [    2   374   686    46    47   121    40    36   125    61]
#  [  145   165 10382   368   446  1015   398   793   907   151]
#  [   38    36  1163  2910   225   229    51   137   384    61]
#  [  342    29  1891   188  2998   340   837   292   639    57]
#  [   64    41  3075   261   247  3333   154   302   575   233]
#  [   20    23  1502    72   385   284  4286    44   344    91]
#  [   77    12  1429   187   351   395    66  3127   560    32]
#  [   78    10  1200   117   262   311   144   371  2160    26]
#  [   23    50  1801   181   157   833   139   200   267  1254]]

# %% [markdown]
# From this confusion matrix and heat map you can see that certain classes are well recognized while others are only begining to be classified. Numerous classes are still confused for asian art more often than being correctly called their own class.

# %% [markdown]
# **Summary** <br>
# After 10 epochs, the model is still "learning". However, at this point I have run into numerous hardware limitations. The machine that I am training this model on is not GPU compatible with PyTorch, so more convolutional layers and more training epochs become not feasible with my current setup. For reference, the 10 epochs used to train this 3 convolutional layer model took around 15 hours to complete and calculating the training accuracy of the network takes around 20 minutes. <br>
# <br>
# Because of these limitations, transfer learning was applied in an attempt to leverage an already trained model to make classifications.

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# The prohibitively long training times on my hardware necessitates the use of an already trained model for this image set (transfer learning). A similar task of art classifcation was performed by Cetinic et al. for the paper *Fine-tuning Convolutional Neural Networks for fine art classification*. In this work, Cetinic classifies images of art from Wikipedia based on the genre of work. Cetinic also compares different methods of tuning a CNN and found that using a network that has been pre-trained for scene recognition performs the best with fewer training epochs. Based on this information, a pre-trained ResNet model was selected for use in feature extraction.

# %%
#because ResNet was trained on RGB images, class must be redefined to create
#three channel tensors
class ArtDepartmentDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, csv_file, root_dir, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.departments_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.images = self.departments_frame.Picture_name
        self.labels = self.departments_frame.department
        
    def __len__(self):
        return len(self.departments_frame)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir,
                                self.departments_frame.iloc[idx, 2])
        dept_name = os.path.join(self.root_dir,
                                self.departments_frame.iloc[idx, 1])
        image = io.imread(img_name, as_gray=True)
        image = np.stack((image,)*3,axis=-1)
        dept = self.departments_frame.iloc[idx, 3]
        sample = {'image': image, 'department': dept}

        if self.transform:
            sample = self.transform(sample)

        return sample
    
class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, department = sample['image'], sample['department']


        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        tens = torch.from_numpy(image)
        image = tens.float()
        in_transform = transforms.Compose([transforms.Normalize(
            mean = [0.485,0.456,0.406], std = [0.229,0.224,0.225])])
        image = in_transform(image)
        return {'image': image,
                'department': department}

# %%
dataset = ArtDepartmentDataset(csv_file='Images/picture_names_and_department.csv',
                                    root_dir='Images/', 
                                    transform=transforms.Compose([
                                               Rescale(250),
                                               RandomCrop(224),
                                               ToTensor()
                                           ]))
batch_size = 8
validation_split = .70
shuffle_dataset = True
random_seed= 42

# Creating data indices for training and validation splits:
dataset_size = len(dataset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
trainset = SubsetRandomSampler(train_indices)
testset = SubsetRandomSampler(val_indices)

trainloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                           sampler=trainset)
testloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                sampler=testset)

classes = ('Ancient Near Eastern Art', 'Arms and Armor','Asian Art', 
           'Costume Institute','Egyptian Art','European Sculpture and Decorative Arts',
           'Greek and Roman Art', 'Islamic Art','Medieval Art', 'The American Wing')

# %%
from torchvision import *

#ResNet18 chosen for its 18 deep layers
net = models.resnet18(pretrained=True)
net
#criterion and optimizer same as defined for CNN trained above
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /home/zach/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# ...
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
def accuracy(out, labels):
    _,pred = torch.max(out, dim=1)
    return torch.sum(pred==labels).item()

num_ftrs = net.fc.in_features
#changing the number of output layers to the number of classes being predicted
net.fc = nn.Linear(num_ftrs, 10)

# %%
writer = SummaryWriter('runs/art_classifier_resnet')

# %%
from skimage import io, transform

dataiter = iter(trainloader)
images = dataiter.next()['image']
labels = dataiter.next()['department']

# create grid of images
img_grid = torchvision.utils.make_grid(images)

# show images
matplotlib_imshow(img_grid, one_channel=True)

# write to tensorboard
writer.add_image('batch_art_images', img_grid)

# %%
writer.add_graph(net, images)
writer.close()

# %%
# %%time

#ideally, a pretrained model will learn in fewer epochs
for epoch in range(5):

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs = data['image']
        labels = data['department']

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 1000 == 999:
            
                writer.add_scalar('training loss',
                                  running_loss / 1000,
                                  epoch * len(trainloader) + i)
                writer.add_figure('predictions vs. actuals',
                                  plot_classes_preds(net, inputs, labels),
                                  global_step=epoch * len(trainloader) + i)
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 2000))
                running_loss = 0.0

print('Finished Training')
# Out:
# [1,  1000] loss: 1.211
# [1,  2000] loss: 1.203
# [1,  3000] loss: 1.204
# [2,  1000] loss: 1.209
# [2,  2000] loss: 1.208
# [2,  3000] loss: 1.205
# [3,  1000] loss: 1.209
# [3,  2000] loss: 1.207
# [3,  3000] loss: 1.207
# [4,  1000] loss: 1.210
# [4,  2000] loss: 1.204
# [4,  3000] loss: 1.203
# [5,  1000] loss: 1.203
# [5,  2000] loss: 1.208
# [5,  3000] loss: 1.208
# Finished Training
# CPU times: user 12h 56min 15s, sys: 5min 26s, total: 13h 1min 42s
# Wall time: 7h 12min 59s

# %%
PATH = './art_classifier_resnet.pth'
torch.save(net.state_dict(), PATH)

# %%
correct = 0
total = 0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
all_preds = torch.tensor([])
all_labels = torch.tensor([])

with torch.no_grad():
    for data in testloader:
        images = data['image']
        labels = data['department']
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        all_preds = torch.cat(
            (all_preds, outputs)
            ,dim=0
        )
        all_labels = torch.cat(
            (all_labels, labels)
            ,dim=0
        )
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of the network on the 10000 test images: 9 %
# Accuracy of Ancient Near Eastern Art :  0 %
# Accuracy of Arms and Armor :  6 %
# Accuracy of Asian Art :  6 %
# Accuracy of Costume Institute :  1 %
# Accuracy of Egyptian Art :  3 %
# Accuracy of European Sculpture and Decorative Arts : 15 %
# Accuracy of Greek and Roman Art : 42 %
# Accuracy of Islamic Art :  0 %
# Accuracy of Medieval Art :  0 %
# Accuracy of The American Wing :  3 %

# %%
preds_correct = get_num_correct(all_preds, all_labels)

print('total correct:', preds_correct)
print('accuracy:', preds_correct / len(all_labels))
# Out:
# total correct: 6103
# accuracy: 0.09444298293124526

# %%
cm = confusion_matrix(all_labels, all_preds.argmax(dim=1))

plt.figure(figsize=(12,12))
plot_confusion_matrix(cm, classes)
# Out:
# Confusion matrix, without normalization
# [[   6  232  357   56  206 1038 2207    3    3  202]
#  [   0   98  108   28   60  279  922    0    1   42]
#  [  16  909 1030  342  882 3250 7708    6    7  620]
#  [   1   94  244   88  302  986 3455    0    3   61]
#  [  12  440  817  140  278 1761 3814    1    6  344]
#  [  16  444  506  234  632 1376 4729    3    2  343]
#  [   8  578  758  136  469 1702 3053    1    8  338]
#  [  19  246  356  116  140 1890 3118    2    9  340]
#  [   7  258  440   61  139 1469 2166    0    3  136]
#  [  13  238  318   77  340  959 2791    0    0  169]]

# %% [markdown]
# Unfortunately, the pretrained ResNet model performs worse at classifying art than even the initial simple convolutional neural network that was designed. The overall accuracy of the classifier was around 9%, and the algorithm failed to significantly decrease training loss over 5 epochs. Additionally, the training of this model took twice as long as either of the CNN worked on before.

# %% [markdown]
# # Conclusions

# %% [markdown]
# *Technical Note:* PyTorch was the the library selected for this project because of its ability to easily switch to between CPU and GPU training for models. The original plan was to perform this work on a computer with a CUDA compatible GPU, but this plan did not work out in time-frame of the project. Training convolutional neural networks on a CPU is slow and inefficient, and greatly hindered the progression of this project.

# %% [markdown]
# ### Summary

# %% [markdown]
# Overall, this project has been successful in creating a convolutional neural network for classifying artworks into different departments. Despite the maximum overall average accuracy of 50% achieved with these data, this classifier would still be useful in a real world context. The classifier demonstrates at least some feature recognition of each class and correctly classifies the majority of the departments regularly. As is, this tool could be implemented along with human oversight. Cases where the model has a high prediction confidence of just one category can be automatically sorted, and cases where confidence is lower can be passed to an expert to make the final curation decision.

# %% [markdown]
# ### Future Directions

# %% [markdown]
# Running experiments to find out what the best hyperparameters are for multiple CNN configurations would be the immediate next step. Due to computational limitations it was not feasible to test the whole range of CNN hyperparameters on this image set, so assumptions had to be made about what would be the best loss function and optimization settings based on previous literature. However these assumptions were made for a different art dataset trying to predict different classifications, making it unlikely that these are truly the best settings for this classifier.
# <br>
# <br>
# This dataset and classifier architecture could also be expanded on to make other classifications such as: which artist made the piece, what artistic movement a piece belongs to, or even the country that the work comes from. These would be interesting classification problems, and could also help in the identification of artwork with unknown origins.
